# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/RV_O_010_R_SR_SK.CSV', sep=';')
df.head()
# Out:
#   Kód štátu          Názov štátu Pohlavie         Ekonomické vekové skupiny  \
# 0       SK0  Slovenská republika      muž  predproduktívny vek (0-14 rokov)
# 1       SK0  Slovenská republika      muž  predproduktívny vek (0-14 rokov)
# 2       SK0  Slovenská republika      muž  predproduktívny vek (0-14 rokov)
# 3       SK0  Slovenská republika      muž  predproduktívny vek (0-14 rokov)
# 4       SK0  Slovenská republika      muž  predproduktívny vek (0-14 rokov)
#
#                                            Vzdelanie    abs.
# 0                                          nezistené    6301
# 1             základné vzdelanie (bližšie neuvedené)       1
# 2     základné vzdelanie - 1. stupeň základnej školy  117157
# 3     základné vzdelanie - 2. stupeň základnej školy      66
# 4  bez ukončeného vzdelania – osoby vo veku 0-14 ...  320751

# %%
df.describe()
# Out:
#                 abs.
# count      92.000000
# mean    59231.195652
# std     93806.632238
# min         1.000000
# 25%      2671.250000
# 50%     16727.500000
# 75%     77318.000000
# max    400487.000000

# %%
# # Pohlavie
display(df.groupby('Pohlavie')['abs.'].sum())
# Out:
# Pohlavie
# muž     2665376
# žena    2783894
# Name: abs., dtype: int64

# %%
# # Vzdelanie
display(df.groupby('Vzdelanie')['abs.'].sum())
# Out:
# Vzdelanie
# bez ukončeného vzdelania – osoby vo veku 0-14 rokov                                                      623199
# bez školského vzdelania – osoby vo veku 15 rokov a viac                                                   14987
# nezistené                                                                                                226004
# stredné odborné (učňovské) vzdelanie bez maturity (bližšie neuvedené)                                      6833
# stredné odborné (učňovské) vzdelanie bez maturity a bez výučného listu (zaškolenie, zaučenie)             90310
# stredné odborné (učňovské) vzdelanie bez maturity s vysvedčením o záverečnej skúške                      112295
# stredné odborné (učňovské) vzdelanie bez maturity s výučným listom                                       837915
# vysokoškolské vzdelanie (bližšie neuvedené)                                                                 444
# vysokoškolské vzdelanie - 1. stupeň (Bc.)                                                                141680
# vysokoškolské vzdelanie - 2. stupeň (Ing.; Mgr.; MUDr.; a i.)                                            802776
# vysokoškolské vzdelanie - 3. stupeň (PhD.; a i.)                                                          56546
# vyššie odborné vzdelanie (bližšie neuvedené)                                                                 43
# vyššie odborné vzdelanie nadstavbové (maturita absolventov učebných odborov stredných odborných škôl)    188088
# vyššie odborné vzdelanie pomaturitné (pomaturitné kvalifikačné)                                           42821
# vyššie odborné vzdelanie vyššie odborné (absolventská skúška, absolventský diplom)                        36749
# základné vzdelanie (bližšie neuvedené)                                                                     7997
# základné vzdelanie - 1. stupeň základnej školy                                                           339243
# základné vzdelanie - 2. stupeň základnej školy                                                           577368
# úplné stredné vzdelanie s maturitou (bližšie neuvedené)                                                    3139
# úplné stredné vzdelanie s maturitou odborné                                                              773856
# úplné stredné vzdelanie s maturitou odborné (učňovské) s výučným listom                                  301596
# úplné stredné vzdelanie s maturitou všeobecné                                                            265381
# Name: abs., dtype: int64

# %%
df.groupby('Ekonomické vekové skupiny').size()
# Out:
# Ekonomické vekové skupiny
# poproduktívny vek (65 a viac rokov)    41
# predproduktívny vek (0-14 rokov)        9
# produktívny vek (15-64 rokov)          42
# dtype: int64

# %%
productive_age = df[df['Ekonomické vekové skupiny']=='produktívny vek (15-64 rokov)']
productive_age.head()
# Out:
#   Kód štátu          Názov štátu Pohlavie      Ekonomické vekové skupiny  \
# 5       SK0  Slovenská republika      muž  produktívny vek (15-64 rokov)
# 6       SK0  Slovenská republika      muž  produktívny vek (15-64 rokov)
# 7       SK0  Slovenská republika      muž  produktívny vek (15-64 rokov)
# 8       SK0  Slovenská republika      muž  produktívny vek (15-64 rokov)
# 9       SK0  Slovenská republika      muž  produktívny vek (15-64 rokov)
#
#                                            Vzdelanie    abs.
# 5                                          nezistené  108406
# 6             základné vzdelanie (bližšie neuvedené)    2937
# 7     základné vzdelanie - 1. stupeň základnej školy   44458
# 8     základné vzdelanie - 2. stupeň základnej školy  199375
# 9  stredné odborné (učňovské) vzdelanie bez matur...    5146

# %%
sns.set_style("whitegrid")
f = plt.figure(figsize=(15, 10))
axes = sns.barplot(data=productive_age, 
                   x='abs.', y='Vzdelanie', hue='Pohlavie')
axes.set_title('Distribution of education by gender at working age (15-64 years)')
axes.set_xlabel("Amount of people")
axes.set_ylabel(None)
pass
